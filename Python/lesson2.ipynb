# %% [markdown]
# 第二节课的笔记

# %%
# 三目运算
a = 10 
b = 20 
a if a > b else b

# %%
# 关键字
import keyword
keyword.kwlist

# %%
# 内置函数
dir(__builtins__)

# %%
# eval函数
eval('3 * 5')

# %%
x = 6
eval('3 * x')

# %%
hello = '你好'
nice_to_see_you = '很高兴见到你'
print(eval('hello + nice_to_see_you'))

# %%
age = eval(input('Please imput your age:'))
print("Your are", age, "years old!",type(age))

# %%
# all(iterable)
#如果对于可迭代对象中所有元素x都等价于True，也就是对于所有元素x都有bool(x)等于True，并返回True
all([1,2,3])

# %%
all(['','a','b','c'])

# %%
# 在python中，任何非空字符串的布尔值都是True，每个字符都是一个长度为1的字符串，因此都是True
all('')

# %%
all([''])

# %%
#any(iterable)
#只要存在元素使bool返回True，则返回True，对于空可迭代对象，返回False
any(['','a','b'])

# %%
any('')

# %%
any([''])

# %%
import sys
print(sys.version)

# %%
import os
os.getcwd

# %%
#form模块名import对象名[as 别名]
from math import sin

# %%
sin(30)#接受的参数是弧度而不是度

# %%
import math as mt

radians = mt.radians(30)
sin(radians)

# %%
from math import pi as PI
sin(PI)

# %%
# '% [-]有负号就是左对齐，没有就是右对齐 [+]正数也显示+号 [10]占用多少字符 [.2]保留几位小数  [f]转换为什么数型 '% x
x = -1235
'%-+10.2f'%x

# %%
print("欢迎来到历史搜查室")
while 1:
    i = (input("请输入你想查询的年份，如需退出请输入退出："))
    if i == 退出:
        break
    if i == 1921: 
        print("这一年中国共产党成立")
    if i == 1949:
        print("这一年中华人民共和国成立")
    if i == 1978:
        print("这一年改革开放")
    if i == 2008:
        print("这一年北京冬奥会")
    if i == 0:
        break
    else:
        print("这一年什么都没有发生")
# Out:
# 欢迎来到历史搜查室
# 请输入你想查询的年份，如需退出请输入退出： 退出
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 while 1:
#       3     i = (input("请输入你想查询的年份，如需退出请输入退出："))
# ----> 4     if i == 退出:
#       5         break
#       6     if i == 1921:
#
# NameError: name '退出' is not defined
