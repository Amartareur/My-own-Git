# %%
print("你好，就是这样")
a = 1
b = 15
a+b
# Out:
# 你好，就是这样
# 16

# %%
c = input("请输入一个数字：")
c = int(c)

# 计算和
sum = a + b + c

# 打印结果
print(a, "+", b, "+", c, "=", sum)
# Out:
# 请输入一个数字： 15
# 1 + 15 + 15 = 31

# %%
# 整数
x = 42 
# 查看数字类型
print(type(x))
# Out:
# <class 'int'>

# %%
# 浮点数
y = 1.7
print(type(y))
# Out:
# <class 'float'>

# %%
z = 0.1 + 0.2
print(z)
#转换二进制，它的结果就是不准确的
# Out:
# 0.30000000000000004

# %%
# 复数（complex）
a = complex(3,4)
print(type(a))

real_part = a.real
imaginary_part = a.imag

print(real_part)
print(imaginary_part)
# Out:
# <class 'complex'>
# 3.0
# 4.0

# %%
triple_quote_str = '''三引号，
可以做到"换行"输出'''
print(triple_quote_str)
# Out:
# 三引号，
# 可以做到"换行"输出

# %%
path = r"C:\Windows\notepad.exe"
print(path)
#原始字符串 r 可以让特殊字符不起作用
# Out:
# C:\Windows\notepad.exe

# %%
#bool
5>3
# Out:
# True

# %%
5<3
# Out:
# False

# %%
#非空字符为True，空字符为False
value = bool("Hello")
print(value)
value = bool("")
print(value)
# Out:
# True
# False

# %%
#False = 0 , True = 1（字母开头必须大写）
1+False
# Out:
# 1

# %%
1+True
# Out:
# 2

# %%
a = 12
b = chr(a)# 转换成字符
c = ord(b)
d = str(a)# 转换成为字符串
print(a, b, c, d)
# Out:
# 12  12 12

# %%
score_computer = 87.5
score_englisht = 93.2
score_math = 90.5
score_sum = score_computer + score_englisht + score_math
score_sum_str = str(score_sum) 
print("三门课程总成绩为："+score_sum_str)
print("三门课程总成绩为：",score_sum_str)#字符串可以用 + 或者 , 来打印

score_int = int(score_sum) 
print("去除小数部分的成绩为：",score_int)#但是整数必须使用 , 来打印
# Out:
# 三门课程总成绩为：271.2
# 三门课程总成绩为： 271.2
# 去除小数部分的成绩为： 271

# %%
#运算符
3+5
# Out:
# 8

# %%
"相同属性的两个量"+"可以用加号相连"
# Out:
# '相同属性的两个量可以用加号相连'

# %%
True + 1
# Out:
# 2

# %%
"abc"*2#乘法就不一样了
# Out:
# 'abcabc'

# %%
[1,2,3]*2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
(1,2,3)*2
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
# / 表示真除法， //表示整除运算
6/3
# Out:
# 2.0

# %%
6/2.3
# Out:
# 2.608695652173913

# %%
6//2.3 #向下取整
# Out:
# 2.0

# %%
-13//10
# Out:
# -2

# %%
#取余数 %
3.0%2
# Out:
# 1.0

# %%
5%2
# Out:
# 1

# %%
6.3%2.1
# Out:
# 2.0999999999999996

# %%
17%-4
# Out:
# -3

# %%
#幂运算 **
2**3
# Out:
# 8

# %%
# = 是赋值， ==是代码中的等于
# a+=b = a+b
# b*=a = b*a

# %%
#比较运算符
1==1
# Out:
# True

# %%
1>=1
# Out:
# True

# %%
2<1
# Out:
# False

# %%
2>=3
# Out:
# False

# %%
'abc' > 'ABC'
# Out:
# True

# %%
#逻辑运算符： and与  or或  not非
5 > 2 and 4 > 2
# Out:
# True

# %%
5 > 2 and 2 > 4 #有一个错就是错
# Out:
# False

# %%
5 > 2 or 4 > 5 #有一个对就是对
# Out:
# True

# %%
3 not in [1,2,3]
# Out:
# False

# %%
0 and 5>3 #0是false
# Out:
# 0

# %%
#成员测试运算符
c = range(1,10,1)
c
# Out:
# range(1, 10)

# %%
1 in range(1,10,1)
# Out:
# True

# %%
3 in [3,4,5]
# Out:
# True

# %%
3 is 3
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /private/var/mobile/Containers/Data/Application/AB122581-8FFE-4B65-8EB7-6E7C525652FA/tmp/ipykernel_3673/30664588.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   3 is 3
# True

# %%
x = [300,300,300]
x[0] is x[1]
# Out:
# True

# %%
x=260 
y=260
x is y #在jupyter notebook中，不同变量内存空间相同，
# Out:
# False

# %%
x=3
id(x)
# Out:
# 5244921296

# %%
x+=3
id(x)
# Out:
# 5244921392
