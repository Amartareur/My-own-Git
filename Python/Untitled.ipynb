# %%
print("你好，就是这样")
a = 1
b = 15
a+b
# Out:
# 你好，就是这样
# 16

# %%
c = input("请输入一个数字：")
c = int(c)

# 计算和
sum = a + b + c

# 打印结果
print(a, "+", b, "+", c, "=", sum)
# Out:
# 请输入一个数字： 13
# 1 + 15 + 13 = 29
